# %% [markdown]
# # Duplicate check

# %% [markdown]
# Entry of the same data record more than once can be considered as a duplicate entry. We often encounter this issue with the datasets. So, we have to check for duplicates in the very initial phase of analysis, so that you do no need to worry later.

# %% [markdown]
# #duplicate
#
# data.drop_duplicates(inplace = True)

# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("Advertising.csv")

# %%
df1=pd.read_csv("Advertising.csv")

# %%
a =df1.head()

# %%
 df1.loc[0:3:, 'radio'].head(10)
# Out:
# 0    37.8
# 1    39.3
# 2    45.9
# 3    41.3
# Name: radio, dtype: float64

# %%
df1.loc[0:2:, 'radio']
# Out:
# 0    37.8
# 1    39.3
# 2    45.9
# Name: radio, dtype: float64

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1["radio"].drop_duplicates(keep="first")
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df1["name"]=1

# %%
df1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df1["place"]="Uttar Pradesh"

# %%
df1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales          place
# 0             1  230.1   37.8       69.2   22.1  Uttar Pradesh
# 1             2   44.5   39.3       45.1   10.4  Uttar Pradesh
# 2             3   17.2   45.9       69.3    9.3  Uttar Pradesh
# 3             4  151.5   41.3       58.5   18.5  Uttar Pradesh
# 4             5  180.8   10.8       58.4   12.9  Uttar Pradesh
# ..          ...    ...    ...        ...    ...            ...
# 195         196   38.2    3.7       13.8    7.6  Uttar Pradesh
# 196         197   94.2    4.9        8.1    9.7  Uttar Pradesh
# 197         198  177.0    9.3        6.4   12.8  Uttar Pradesh
# 198         199  283.6   42.0       66.2   25.5  Uttar Pradesh
# 199         200  232.1    8.6        8.7   13.4  Uttar Pradesh
#
# [200 rows x 6 columns]

# %%
df1['place'] = df1['place'].str.lower()

# %%
df1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales          place
# 0             1  230.1   37.8       69.2   22.1  uttar pradesh
# 1             2   44.5   39.3       45.1   10.4  uttar pradesh
# 2             3   17.2   45.9       69.3    9.3  uttar pradesh
# 3             4  151.5   41.3       58.5   18.5  uttar pradesh
# 4             5  180.8   10.8       58.4   12.9  uttar pradesh
# ..          ...    ...    ...        ...    ...            ...
# 195         196   38.2    3.7       13.8    7.6  uttar pradesh
# 196         197   94.2    4.9        8.1    9.7  uttar pradesh
# 197         198  177.0    9.3        6.4   12.8  uttar pradesh
# 198         199  283.6   42.0       66.2   25.5  uttar pradesh
# 199         200  232.1    8.6        8.7   13.4  uttar pradesh
#
# [200 rows x 6 columns]

# %%
df1['place'] = df1['place'].str.title()

# %%
df1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales          place
# 0             1  230.1   37.8       69.2   22.1  Uttar Pradesh
# 1             2   44.5   39.3       45.1   10.4  Uttar Pradesh
# 2             3   17.2   45.9       69.3    9.3  Uttar Pradesh
# 3             4  151.5   41.3       58.5   18.5  Uttar Pradesh
# 4             5  180.8   10.8       58.4   12.9  Uttar Pradesh
# ..          ...    ...    ...        ...    ...            ...
# 195         196   38.2    3.7       13.8    7.6  Uttar Pradesh
# 196         197   94.2    4.9        8.1    9.7  Uttar Pradesh
# 197         198  177.0    9.3        6.4   12.8  Uttar Pradesh
# 198         199  283.6   42.0       66.2   25.5  Uttar Pradesh
# 199         200  232.1    8.6        8.7   13.4  Uttar Pradesh
#
# [200 rows x 6 columns]

# %% [markdown]
# # Concatination

# %%
df2=df1.head()

# %%
df2
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales          place
# 0           1  230.1   37.8       69.2   22.1  Uttar Pradesh
# 1           2   44.5   39.3       45.1   10.4  Uttar Pradesh
# 2           3   17.2   45.9       69.3    9.3  Uttar Pradesh
# 3           4  151.5   41.3       58.5   18.5  Uttar Pradesh
# 4           5  180.8   10.8       58.4   12.9  Uttar Pradesh

# %%
df2["place"]=["U.p","M.P","A.p","Delhi","u.p"]
# Out:
# C:\Users\Windows\AppData\Local\Temp/ipykernel_13920/2795766186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["place"]=["U.p","M.P","A.p","Delhi","u.p"]

# %%
df2["newspaper"]
# Out:
# 0    69.2
# 1    45.1
# 2    69.3
# 3    58.5
# 4    58.4
# Name: newspaper, dtype: float64

# %%
df3=pd.DataFrame({"state":["U.p","M.P","A.p","Delhi","u.p"]})

# %%
df3
# Out:
#    state
# 0    U.p
# 1    M.P
# 2    A.p
# 3  Delhi
# 4    u.p

# %%
pd.concat([df2,df3],axis=1)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales          place  state
# 0           1  230.1   37.8       69.2   22.1  Uttar Pradesh    U.p
# 1           2   44.5   39.3       45.1   10.4  Uttar Pradesh    M.P
# 2           3   17.2   45.9       69.3    9.3  Uttar Pradesh    A.p
# 3           4  151.5   41.3       58.5   18.5  Uttar Pradesh  Delhi
# 4           5  180.8   10.8       58.4   12.9  Uttar Pradesh    u.p

# %%
pd.concat([df2,df3],axis=1)  #axis=1 for column, axix=0 for row
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales          place  state
# 0           1  230.1   37.8       69.2   22.1  Uttar Pradesh    U.p
# 1           2   44.5   39.3       45.1   10.4  Uttar Pradesh    M.P
# 2           3   17.2   45.9       69.3    9.3  Uttar Pradesh    A.p
# 3           4  151.5   41.3       58.5   18.5  Uttar Pradesh  Delhi
# 4           5  180.8   10.8       58.4   12.9  Uttar Pradesh    u.p

# %%
df2.drop(["state"],axis=1)

# %% [markdown]
# # web scrapping

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import pandas as pd

# %%
client = uReq("https://yoshops.com/products/reliance-jio-phone1")

# %%
client

# %%
read_data = client.read()

# %%
read_data
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n\n\n<title>Jio Phone | Yoshops.com | India&#39;s Online Store For Toys And  Electronics Item</title>\n<meta charset="utf-8" />\n<meta http-equiv=\'X-UA-Compatible\' content=\'IE=edge,chrome=1\' />\n<meta content="text/html; charset=UTF-8" http-equiv="Content-Type" />\n<meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport">\n\n\n<meta content="Buy JIO phone  Rs.1499, jio phone,jio phone booking online,jio phone cover,jio phone feature,jio phone free,jio phone free offer,jio phone in 1500,jio phone in 1500 rupees,jio phone in keypad,jio phone,jio phone at 1500,jio phone book online" name="description">\n\n\n\n<meta content="authenticity_token" name="csrf-param">\n\n\n<meta content="nYbqCigLnrnCLUJvlTWdjll8wrZNJE4Txy5kGpoR9VwYxUWaCo63v/ogoJ/852IYZTZ+kzKE/TGgSY07AL56+A==" name="csrf-token">\n\n\n\n<meta property="og:title" content="Reliance Jio Phone" />\n<meta property="og:type" content="product" />\n<meta property="og:p
# ...

# %%
soup = bs(read_data,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Jio Phone | Yoshops.com | India's Online Store For Toys And  Electronics Item</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport"/>
# <meta content="Buy JIO phone  Rs.1499, jio phone,jio phone booking online,jio phone cover,jio phone feature,jio phone free,jio phone free offer,jio phone in 1500,jio phone in 1500 rupees,jio phone in keypad,jio phone,jio phone at 1500,jio phone book online" name="description"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="nYbqCigLnrnCLUJvlTWdjll8wrZNJE4Txy5kGpoR9VwYxUWaCo63v/ogoJ/852IYZTZ+kzKE/TGgSY07AL56+A==" name="csrf-token"/>
# <meta content="Reliance Jio Phone" property="og:title">
# <meta content="product" property="og:type">
# ...

# %%
product_name = soup.find("h1",{"class":"single-product-title"})

# %%
product_name
# Out:
# <h1 class="single-product-title" id="product-name">Reliance Jio Phone</h1>

# %%
product_name.text
# Out:
# 'Reliance Jio Phone'

# %%
product_detail = soup.find("div",{"class":"col-sm-5"})

# %%
product_detail.div.div.div["data-description"]
# Out:
# 'Product Detail: Brand Reliance Jio Model FM90 Rs.1499 GENERAL Form factor Bar Removable battery No Colours Black SAR value NA DISPLAY Screen size (inches) 2.40 Touchscreen No Resolution 240x320 pixels \xa0Product Description: Get your Effectively Free JioPhone; just pay Security Deposit of INR 1,500. Unlimited Voice & Data at Rs. 49 for 28 days | 4G VoLTE with HD voice calls and Video calling. Access to Jio apps – 1 cr+ songs with JioMusic, 6000+ movies with JioCinema, 400+ channels with JioTV, Breaking news in your language with JioXpressNews, and many more. HelloJio, your own voice assistant. Speak to it to make calls, send SMS, open apps, play music and more. 2MP rear and 0.3MP front camera | Expandable memory upto 128GB | Internal Storage 4GB. Visit nearest Reliance Digital or Jio Store for Device/Sim activation. 2000mAh battery with Talktime upto 12 Hours and Standby Time upto 15 Days. FM radio (no need to connect headphone), Torch, Wi-Fi, Bluetooth, Internet Browser. Project o
# ...

# %%
product_detail1 = soup.find("div",{"class":"single-product-description"})

# %%
product_detail1.text
# Out:
# '\n\nProduct Detail:Brand Reliance JioModel FM90Rs.1499GENERALForm factor BarRemovable battery NoColours BlackSAR value NADISPLAYScreen size (inches) 2.40Touchscreen NoResolution 240x320 pixels\xa0Product Description:Get your Effectively Free JioPhone; just pay Security Deposit of INR 1,500. Unlimited Voice & Data at Rs. 49 for 28 days | 4G VoLTE with HD voice calls and Video calling. Access to Jio apps – 1 cr+ songs with JioMusic, 6000+ movies with JioCinema, 400+ channels with JioTV, Breaking news in your language with JioXpressNews, and many more. HelloJio, your own voice assistant. Speak to it to make calls, send SMS, open apps, play music and more. 2MP rear and 0.3MP front camera | Expandable memory upto 128GB | Internal Storage 4GB. Visit nearest Reliance Digital or Jio Store for Device/Sim activation. 2000mAh battery with Talktime upto 12 Hours and Standby Time upto 15 Days. FM radio (no need to connect headphone), Torch, Wi-Fi, Bluetooth, Internet Browser. Project on big scre
# ...

# %%
product_image = soup.find("img",{"id":"product-image"})

# %%
product_image
# Out:
# <img alt="Reliance Jio Phone" class="single-product-img" id="product-image" src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1354_original/:/rs=w:600,h:600"/>

# %%
product_image["src"]
# Out:
# 'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1354_original/:/rs=w:600,h:600'
